# %%
import numpy as np
import math

def leibniz(n):
    pi_sum = 0.0
    for j in range(n):
        pi_sum += (-1)**j / (2*j + 1)
    return 4 * pi_sum

for i in range(100, 5001, 100):
    estPI = leibniz(i)
    relative_error = abs(estPI - math.pi) / math.pi
    print( i, relative_error)
# Out:
# 100 0.00318301929431018
# 200 0.001591539484045989
# 300 0.001061030006672841
# 400 0.0007957734720706582
# 500 0.000636619135750372
# 600 0.0005305161085596649
# 700 0.00045472817682973846
# 800 0.00039788720230457477
# 900 0.000353677542155349
# 1000 0.0003183098066059948
# 1100 0.00028937256401525733
# 1200 0.0002652581924342223
# 1300 0.00024485372238193846
# 1400 0.0002273641754167515
# 1500 0.00021220656721108246
# 1600 0.00019894365943672938
# 1700 0.00018724109332290856
# 1800 0.0001768388120132509
# 1900 0.0001675315074430701
# 2000 0.0001591549331452938
# 2100 0.0001515761276852106
# 2200 0.00014468630442799474
# 2300 0.00013839559614847166
# 2400 0.0001326291134867456
# 2500 0.00012732394938037403
# 2600 0.0001224268747737047
# 2700 0.00011789254639482
# 2800 0.00011368209858290424
# 2900 0.0001097620264549851
# 3000 0.00010610329244741256
# 3100 0.00010268060577533156
# 3200 9.94718370035312e-05
# 3300 9.645753905293071e-05
# 3400 9.362055273419335e-05
# ...
